# %%
using ImageCore, Images, Plots
using JIVECore

# %%
path = "blobs.png"
img = JIVECore.Files.loadImage(path)
# Out:
# 254×256 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.843,0.843,0.843)  …  RGB{N0f8}(0.216,0.216,0.216)
#  RGB{N0f8}(0.78,0.78,0.78)        RGB{N0f8}(0.153,0.153,0.153)
#  RGB{N0f8}(0.749,0.749,0.749)     RGB{N0f8}(0.09,0.09,0.09)
#  RGB{N0f8}(0.843,0.843,0.843)     RGB{N0f8}(0.09,0.09,0.09)
#  RGB{N0f8}(0.937,0.937,0.937)     RGB{N0f8}(0.09,0.09,0.09)
#  RGB{N0f8}(0.906,0.906,0.906)  …  RGB{N0f8}(0.09,0.09,0.09)
#  RGB{N0f8}(0.875,0.875,0.875)     RGB{N0f8}(0.09,0.09,0.09)
#  RGB{N0f8}(0.843,0.843,0.843)     RGB{N0f8}(0.09,0.09,0.09)
#  RGB{N0f8}(0.812,0.812,0.812)     RGB{N0f8}(0.09,0.09,0.09)
#  RGB{N0f8}(0.812,0.812,0.812)     RGB{N0f8}(0.122,0.122,0.122)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.812,0.812,0.812)  …  RGB{N0f8}(0.78,0.78,0.78)
#  RGB{N0f8}(0.78,0.78,0.78)        RGB{N0f8}(0.78,0.78,0.78)
#  RGB{N0f8}(0.749,0.749,0.749)     RGB{N0f8}(0.78,0.78,0.78)
#  RGB{N0f8}(0.749,0.749,0.749)     RGB{N0f8}(0.812,0.812,0.812)
# ...

# %%
JIVECore.Process.adjContrast(img, -.5)
# Out:
# 254×256 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.8,0.8,0.8)        …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.698,0.698,0.698)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.651,0.651,0.651)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.8,0.8,0.8)           RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.949,0.949,0.949)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.902,0.902,0.902)  …  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.851,0.851,0.851)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.8,0.8,0.8)           RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.749,0.749,0.749)     RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(0.749,0.749,0.749)     RGB{N0f8}(0.0,0.0,0.0)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.749,0.749,0.749)  …  RGB{N0f8}(0.698,0.698,0.698)
#  RGB{N0f8}(0.698,0.698,0.698)     RGB{N0f8}(0.698,0.698,0.698)
#  RGB{N0f8}(0.651,0.651,0.651)     RGB{N0f8}(0.698,0.698,0.698)
#  RGB{N0f8}(0.651,0.651,0.651)     RGB{N0f8}(0.749,0.749,0.749)
# ...

# %%
JIVECore.Process.imHistogram(Gray.(img),true)

# %%
JIVECore.Process.autoContrast(img, algorithm = JIVECore.Process.Equalization)
# Out:
# 254×256 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.804,0.804,0.804)  …  RGB{N0f8}(0.153,0.153,0.153)
#  RGB{N0f8}(0.529,0.529,0.529)     RGB{N0f8}(0.086,0.086,0.086)
#  RGB{N0f8}(0.471,0.471,0.471)     RGB{N0f8}(0.031,0.031,0.031)
#  RGB{N0f8}(0.804,0.804,0.804)     RGB{N0f8}(0.031,0.031,0.031)
#  RGB{N0f8}(0.996,0.996,0.996)     RGB{N0f8}(0.031,0.031,0.031)
#  RGB{N0f8}(0.976,0.976,0.976)  …  RGB{N0f8}(0.031,0.031,0.031)
#  RGB{N0f8}(0.922,0.922,0.922)     RGB{N0f8}(0.031,0.031,0.031)
#  RGB{N0f8}(0.804,0.804,0.804)     RGB{N0f8}(0.031,0.031,0.031)
#  RGB{N0f8}(0.643,0.643,0.643)     RGB{N0f8}(0.031,0.031,0.031)
#  RGB{N0f8}(0.643,0.643,0.643)     RGB{N0f8}(0.059,0.059,0.059)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.643,0.643,0.643)  …  RGB{N0f8}(0.529,0.529,0.529)
#  RGB{N0f8}(0.529,0.529,0.529)     RGB{N0f8}(0.529,0.529,0.529)
#  RGB{N0f8}(0.471,0.471,0.471)     RGB{N0f8}(0.529,0.529,0.529)
#  RGB{N0f8}(0.471,0.471,0.471)     RGB{N0f8}(0.643,0.643,0.643)
# ...

# %%
JIVECore.Process.imComplement(img)
# Out:
# 254×256 Array{RGB{N0f8},2} with eltype RGB{N0f8}:
#  RGB{N0f8}(0.157,0.157,0.157)  …  RGB{N0f8}(0.784,0.784,0.784)
#  RGB{N0f8}(0.22,0.22,0.22)        RGB{N0f8}(0.847,0.847,0.847)
#  RGB{N0f8}(0.251,0.251,0.251)     RGB{N0f8}(0.91,0.91,0.91)
#  RGB{N0f8}(0.157,0.157,0.157)     RGB{N0f8}(0.91,0.91,0.91)
#  RGB{N0f8}(0.063,0.063,0.063)     RGB{N0f8}(0.91,0.91,0.91)
#  RGB{N0f8}(0.094,0.094,0.094)  …  RGB{N0f8}(0.91,0.91,0.91)
#  RGB{N0f8}(0.125,0.125,0.125)     RGB{N0f8}(0.91,0.91,0.91)
#  RGB{N0f8}(0.157,0.157,0.157)     RGB{N0f8}(0.91,0.91,0.91)
#  RGB{N0f8}(0.188,0.188,0.188)     RGB{N0f8}(0.91,0.91,0.91)
#  RGB{N0f8}(0.188,0.188,0.188)     RGB{N0f8}(0.878,0.878,0.878)
#  ⋮                             ⋱  ⋮
#  RGB{N0f8}(0.188,0.188,0.188)  …  RGB{N0f8}(0.22,0.22,0.22)
#  RGB{N0f8}(0.22,0.22,0.22)        RGB{N0f8}(0.22,0.22,0.22)
#  RGB{N0f8}(0.251,0.251,0.251)     RGB{N0f8}(0.22,0.22,0.22)
#  RGB{N0f8}(0.251,0.251,0.251)     RGB{N0f8}(0.188,0.188,0.188)
# ...
